# %%
# 텐서플로를 통해 회귀선 구하기

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 9.29, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

x_bar = sum(X) / len(X)
y_bar = sum(Y) / len(Y)

a = tf.Variable(random.random())
b = tf.Variable(random.random())

def compute_loss():
  y_pred = a * X + b
  loss = tf.reduce_mean((Y - y_pred) ** 2)
  return loss

optimizer = tf.optimizers.Adam(lr = 0.07)
for i in range(1000):
  optimizer.minimize(compute_loss, var_list = [a, b])
  if i % 100 == 99:
    print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'loss:', compute_loss().numpy())

line_x = np.arange(min(X), max(X), 0.01)
line_y = a * line_x + b

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Population Rage (%)')
plt.show()
# Out:
# 99 a: 0.003878567 b: 6.4736295 loss: 88.534256
# 199 a: -0.23203921 b: 10.921534 loss: 30.5452
# 299 a: -0.3678522 b: 13.474339 loss: 15.093271
# 399 a: -0.43020284 b: 14.646404 loss: 12.354518
# 499 a: -0.4529037 b: 15.073141 loss: 12.038051
# 599 a: -0.45948103 b: 15.196787 loss: 12.014252
# 699 a: -0.46100074 b: 15.225349 loss: 12.01309
# 799 a: -0.46127912 b: 15.230589 loss: 12.013054
# 899 a: -0.46131942 b: 15.231341 loss: 12.013053
# 999 a: -0.46132323 b: 15.231418 loss: 12.013054

# %%
# 다항회귀(2차)

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

a = tf.Variable(random.random())
b = tf.Variable(random.random())
c = tf.Variable(random.random())

def compute_loss():
  y_pred = a * X * X + b * X + c
  loss = tf.reduce_mean((Y - y_pred) ** 2)
  return loss

optimizer = tf.keras.optimizers.Adam(lr = 0.07)
for i in range(1000):
  optimizer.minimize(compute_loss, var_list = [a, b, c])

  if i % 100 == 99:
    print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'c:', c.numpy(), 'loss:', compute_loss().numpy())

  line_x = np.arange(min(X), max(X), 0.01)
  line_y = a * line_x * line_x + b * line_x + c

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Popluation Rate (%)')
plt.show()
# Out:
# 99 a: 4.1657066 b: -6.08466 c: 6.0171337 loss: 74.18755
# 199 a: 3.0675876 b: -4.8375897 c: 9.825535 loss: 35.204887
# 299 a: 1.4987974 b: -2.544333 c: 12.539092 loss: 17.749973
# 399 a: 0.47434622 b: -1.0443007 c: 14.303676 loss: 11.564351
# 499 a: -0.0994779 b: -0.2044487 c: 15.294842 loss: 9.878933
# 599 a: -0.37978125 b: 0.2057702 c: 15.77929 loss: 9.522892
# 699 a: -0.49955904 b: 0.38105983 c: 15.986323 loss: 9.464388
# 799 a: -0.54440445 b: 0.4466881 c: 16.063843 loss: 9.45691
# 899 a: -0.55910754 b: 0.46820658 c: 16.089252 loss: 9.456172
# 999 a: -0.56331456 b: 0.4743632 c: 16.096525 loss: 9.456114

# %%
# 다항회귀(3차)

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

a = tf.Variable(random.random())
b = tf.Variable(random.random())
c = tf.Variable(random.random())
d = tf.Variable(random.random())

def compute_loss():
  y_pred = a * X * X * X + b * X * X + c * X + d
  loss = tf.reduce_mean((Y - y_pred) ** 2)
  return loss

optimizer = tf.keras.optimizers.Adam(lr = 0.07)
for i in range(1000):
  optimizer.minimize(compute_loss, var_list = [a, b, c, d])

  if i % 100 == 99:
    print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'c:', c.numpy(), 'd:', d.numpy(), 'loss:', compute_loss().numpy())

  line_x = np.arange(min(X), max(X), 0.01)
  line_y = a * line_x * line_x * line_x + b * line_x * line_x + c * line_x + d

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Popluation Rate (%)')
plt.show()
# Out:
# 99 a: -1.2499312 b: 5.842232 c: -3.4870641 d: 6.9042306 loss: 56.934162
# 199 a: -1.9143709 b: 6.5216827 c: -2.1325996 d: 10.333779 loss: 28.445936
# 299 a: -1.5196804 b: 4.66369 c: -0.89225686 d: 12.408317 loss: 18.730942
# 399 a: -0.771814 b: 2.3352487 c: -0.54834133 d: 13.869991 loss: 13.364943
# 499 a: -0.081615776 b: 0.3187028 c: -0.46030068 d: 14.962297 loss: 10.417814
# 599 a: 0.4459174 b: -1.2050194 c: -0.4230493 d: 15.761853 loss: 8.9787445
# 699 a: 0.81422603 b: -2.2667832 c: -0.40046713 d: 16.315659 loss: 8.3564825
# 799 a: 1.0542096 b: -2.958351 c: -0.3861678 d: 16.675894 loss: 8.117758
# 899 a: 1.2007924 b: -3.380722 c: -0.37749848 d: 16.895824 loss: 8.036478
# 999 a: 1.2847931 b: -3.6227565 c: -0.37254354 d: 17.021833 loss: 8.011942

# %%
# 다항회귀(4차)

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

a = tf.Variable(random.random())
b = tf.Variable(random.random())
c = tf.Variable(random.random())
d = tf.Variable(random.random())
e = tf.Variable(random.random())

def compute_loss():
  y_pred = a * X * X * X * X + b * X * X * X + c * X * X + d * X + e
  loss = tf.reduce_mean((Y - y_pred) ** 2)
  return loss

optimizer = tf.keras.optimizers.Adam(lr = 0.07)
for i in range(1000):
  optimizer.minimize(compute_loss, var_list = [a, b, c, d, e])

  if i % 100 == 99:
    print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'c:', c.numpy(), 'd:', d.numpy(), 'e:', e.numpy(), 'loss:', compute_loss().numpy())

  line_x = np.arange(min(X), max(X), 0.01)
  line_y = a * line_x * line_x * line_x * line_x + b * line_x * line_x * line_x + c * line_x * line_x + d * line_x + e

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Popluation Rate (%)')
plt.show()
# Out:
# 99 a: -0.18689005 b: -0.03118368 c: 4.024638 d: -3.7129276 e: 6.593586 loss: 64.709045
# 199 a: -0.639268 b: 0.2337377 c: 5.76753 d: -3.365275 e: 10.252785 loss: 27.310244
# 299 a: -0.8101632 b: 0.7609493 c: 4.937329 d: -2.5492983 e: 12.262661 loss: 18.279915
# 399 a: -0.8099501 b: 1.3106321 c: 3.1634622 d: -2.2072995 e: 13.532209 loss: 13.734596
# 499 a: -0.78598726 b: 1.8466948 c: 1.3899375 d: -2.0697815 e: 14.484529 loss: 10.845075
# 599 a: -0.78413874 b: 2.356117 c: -0.08970601 d: -2.0320776 e: 15.231437 loss: 9.127701
# 699 a: -0.81086886 b: 2.8341386 c: -1.2310162 d: -2.0712702 e: 15.797883 loss: 8.183197
# 799 a: -0.86343503 b: 3.2816803 c: -2.0632524 d: -2.1756914 e: 16.20517 loss: 7.6898127
# 899 a: -0.9370119 b: 3.7027576 c: -2.6396549 d: -2.3327465 e: 16.481445 loss: 7.4327173
# 999 a: -1.0263839 b: 4.1023755 c: -3.0193071 d: -2.5293605 e: 16.657156 loss: 7.2883

# %%
# 다항회귀(5차)

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import random

X = [0.3, -0.78, 1.26, 0.03, 1.11, 0.24, -0.24, -0.47, -0.77, -0.37, -0.85, -0.41, -0.27, 0.02, -0.76, 2.66]
Y = [12.27, 14.44, 11.87, 18.75, 17.52, 16.37, 19.78, 19.51, 12.65, 14.74, 10.72, 21.94, 12.83, 15.51, 17.14, 14.42]

a = tf.Variable(random.random())
b = tf.Variable(random.random())
c = tf.Variable(random.random())
d = tf.Variable(random.random())
e = tf.Variable(random.random())
f = tf.Variable(random.random())

def compute_loss():
  y_pred = a * X * X * X * X * X + b * X * X * X * X + c * X * X * X + d * X * X + e * X + f
  loss = tf.reduce_mean((Y - y_pred) ** 2)
  return loss

optimizer = tf.keras.optimizers.Adam(lr = 0.07)
for i in range(1000):
  optimizer.minimize(compute_loss, var_list = [a, b, c, d, e, f])

  if i % 100 == 99:
    print(i, 'a:', a.numpy(), 'b:', b.numpy(), 'c:', c.numpy(), 'd:', d.numpy(), 'e:', e.numpy(),'f:', f.numpy(), 'loss:', compute_loss().numpy())

  line_x = np.arange(min(X), max(X), 0.01)
  line_y = a * line_x * line_x * line_x * line_x * line_x + b * line_x * line_x * line_x * line_x + c * line_x * line_x * line_x + d * line_x * line_x + e * line_x + f

plt.plot(line_x, line_y, 'r-')
plt.plot(X, Y, 'bo')
plt.xlabel('Population Growth Rate (%)')
plt.ylabel('Elderly Popluation Rate (%)')
plt.show()
# Out:
# 99 a: 0.0009870732 b: -0.1166945 c: 0.04046612 d: 2.619037 e: -2.0240917 f: 6.730626 loss: 69.20655
# 199 a: -0.12475031 b: -0.0901405 c: 0.18777135 d: 4.116489 e: -2.8484404 f: 10.572181 loss: 25.943962
# 299 a: -0.1292589 b: -0.18673664 c: 0.3723848 d: 3.9040349 e: -2.3649824 f: 12.568403 loss: 17.246723
# 399 a: -0.060355008 b: -0.33135462 c: 0.51646984 d: 2.8720405 e: -1.8023382 f: 13.6886425 loss: 13.745784
# 499 a: 0.026402451 b: -0.4819396 c: 0.64713204 d: 1.6894137 e: -1.3830513 f: 14.483865 loss: 11.417494
# 599 a: 0.10563318 b: -0.6234203 c: 0.7885881 d: 0.6196769 e: -1.0735787 f: 15.12448 loss: 9.876837
# 699 a: 0.17041388 b: -0.751366 c: 0.94718 d: -0.2676413 e: -0.8568535 f: 15.642103 loss: 8.925549
# 799 a: 0.22012705 b: -0.8653943 c: 1.1229208 d: -0.96737415 e: -0.72668886 f: 16.044882 loss: 8.369921
# 899 a: 0.25617594 b: -0.96700615 c: 1.3145247 d: -1.4967406 e: -0.6744849 f: 16.344515 loss: 8.053902
# ...
